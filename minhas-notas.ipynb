# %% [markdown]
# # Anotações sobre as árvores de decisão

# %% [markdown]
# É um modelo supervisionado que é utilizado para classificações (decisão), utiliza dados encadeados e é de fácil interpretabilidade.
