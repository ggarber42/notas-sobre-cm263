# %% [markdown]
# ## Pipeline ML - KNN

# %% [markdown]
# exemplo utilizando o KNN

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ### Carregando os dados

# %%
iris = load_iris()
#print(iris)
'''
{'data': array([[5.1, 3.5, 1.4, 0.2],
       [4.9, 3. , 1.4, 0.2],
       [4.7, 3.2, 1.3, 0.2],
       [4.6, 3.1, 1.5, 0.2],
       [5. , 3.6, 1.4, 0.2],
       [5.4, 3.9, 1.7, 0.4],
       [4.6, 3.4, 1.4, 0.3],
       [5. , 3.4, 1.5, 0.2],
'''
# Out:
# "\n{'data': array([[5.1, 3.5, 1.4, 0.2],\n       [4.9, 3. , 1.4, 0.2],\n       [4.7, 3.2, 1.3, 0.2],\n       [4.6, 3.1, 1.5, 0.2],\n       [5. , 3.6, 1.4, 0.2],\n       [5.4, 3.9, 1.7, 0.4],\n       [4.6, 3.4, 1.4, 0.3],\n       [5. , 3.4, 1.5, 0.2],\n"

# %%
X_raw = iris.data
y_raw = iris.target

#print(X)
#print(Y)

# %%
print("Features:", iris.feature_names)
print("Classes:", iris.target_names)
print("X shape:", X_raw.shape)
print("y shape:", y_raw.shape)
# Out:
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Classes: ['setosa' 'versicolor' 'virginica']
# X shape: (150, 4)
# y shape: (150,)

# %%
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

# %%
# convertendo os dados do target (aprendizado supervisionado)

df["target"] = iris.target

# %%
df["species"] = df["target"].map({
    0: "setosa",
    1: "versicolor",
    2: "virginica"
})

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %% [markdown]
# ### Análise Exploratória dos dados (EDA)

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
#  5   species            150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
df.drop(columns=["target", "species"]).describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.drop(columns=["target", "species"]).isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### Seleção de features para o modelo

# %% [markdown]
# #### Matriz de correlação

# %%
corr_matrix = df.drop(columns="species").corr()

corr_matrix
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
## de um jeito mais bonito
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    vmin=-1,
    vmax=1
)

plt.title("Correlation Matrix")
plt.show()

# %%
features = [ "petal length (cm)", "petal width (cm)"]

X = df[features]
y = df["target"]

# %% [markdown]
# ### Treinamento

# %% [markdown]
# #### sem normalização

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2, # 80% 20% split
    random_state=42, #fix random number generator
    stratify=y  #mantém as mesmas proporções de cada classe nos testes
)

# %%
knn = KNeighborsClassifier(n_neighbors=5) # n é hiperparâmetro
knn.fit(X_train, y_train) # rodando o modelo
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667

# %%
print(classification_report(
    y_test,
    y_pred,
    target_names=iris.target_names
))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      0.90      0.95        10
#    virginica       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=iris.target_names,
    yticklabels=iris.target_names
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### com normalização

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test) # para os dados de teste apenas aplica-se a escala e não o fit

# %%
knn.fit(X_train_scaled, y_train)
y_pred = knn.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667

# %%
cm = confusion_matrix(y_pred, y_test)
print(cm)
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  1 10]]

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=iris.target_names,
    yticklabels=iris.target_names
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### Procurando o melhor k (hiperparâmetro)

# %%
results = []

for k in range(1,21):
    knn = KNeighborsClassifier(
        n_neighbors = k
    )
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    results.append({
        "k": k,
        "accuracy": accuracy_score(y_test, y_pred)
    })

# %%
results_df = pd.DataFrame(results)

best_row = results_df.loc[
    results_df["accuracy"].idxmax()
]

print("\nBest K:")
print(best_row)
# Out:
# Best K:
# k           4.0
# accuracy    1.0
# Name: 3, dtype: float64

# %%
results_df.plot(
    x="k",
    y="accuracy",
    marker="o"
)

plt.title("KNN: K vs Accuracy")
plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Accuracy")
plt.grid()

plt.show()
